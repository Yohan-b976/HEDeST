# %%
# %load_ext autoreload
# %autoreload 2

from utils import bar_plot_perf

# %% [markdown]
# ## Quantitative comparison

# %%
file_mhast = "results/mhast/Ovarian_Cancer_full_simulation/4_moco_clusters_30spots_balanced_5mean_5var_mhast.xlsx"
file_hedest_no_adj = "results/mhast/Ovarian_Cancer_full_simulation/HEDeST/4_moco_clusters_30spots_balanced_5mean_5var/metrics_cells_best.xlsx"
file_hedest = "results/mhast/Ovarian_Cancer_full_simulation/HEDeST/4_moco_clusters_30spots_balanced_5mean_5var/metrics_cells_best_adj.xlsx"

files_info =  [
    (file_mhast, 'Summary', 'random', 'grey'),
    (file_mhast, 'Metrics After', 'MHAST', 'skyblue'),
    (file_hedest_no_adj, 'summary', 'HEDeST (no PPSA)', 'plum'),
    (file_hedest, 'summary', 'HEDeST', 'darkorchid'),
]

bar_plot_perf(files_info, 
              level="cells",
              figsize=(9, 6),
            #   savefig='results/mhast/Ovarian_Cancer_full_simulation/figures/barplot_benchmark_balanced.svg'
            )
# Out:
# Figure saved to results/mhast/Ovarian_Cancer_full_simulation_v2/figures/barplot_benchmark_balanced.svg

# %%
file_mhast = "results/mhast/Ovarian_Cancer_full_simulation/4_moco_clusters_30spots_imbalanced_5mean_5var_mhast.xlsx"
file_hedest_no_adj = "results/mhast/Ovarian_Cancer_full_simulation/HEDeST/4_moco_clusters_30spots_imbalanced_5mean_5var/metrics_cells_best.xlsx"
file_hedest = "results/mhast/Ovarian_Cancer_full_simulation/HEDeST/4_moco_clusters_30spots_imbalanced_5mean_5var/metrics_cells_best_adj.xlsx"

files_info =  [
    (file_mhast, 'Summary', 'random', 'grey'),
    (file_mhast, 'Metrics After', 'MHAST', 'skyblue'),
    (file_hedest_no_adj, 'summary', 'HEDeST (no PPSA)', 'plum'),
    (file_hedest, 'summary', 'HEDeST', 'darkorchid'),
]

bar_plot_perf(files_info, 
              level="cells",
              figsize=(9, 6),
            #   savefig='results/mhast/Ovarian_Cancer_full_simulation/figures/barplot_benchmark_imbalanced.svg'
            )
# Out:
# Figure saved to results/mhast/Ovarian_Cancer_full_simulation_v2/figures/barplot_benchmark_imbalanced.svg
